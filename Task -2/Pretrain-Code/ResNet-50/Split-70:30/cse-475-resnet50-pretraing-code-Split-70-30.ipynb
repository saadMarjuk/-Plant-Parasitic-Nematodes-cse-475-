# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/dataset_readme.md
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/dataset_metadata.csv
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (59).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (181).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (104).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (118).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (47).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (135).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (205).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (58).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (75).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (192).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (84).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (162).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (100).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (11).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (74).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (123).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (175).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (33).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (102).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (95).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (5).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (46).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (89).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (16).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (153).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (71).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (122).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (199).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (193).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (2).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (31).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (36).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (32).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (171).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (9).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (109).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (60).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (114).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (189).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (39).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (90).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (179).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (8).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (184).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (62).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (154).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (103).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (18).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (13).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (3).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (14).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (208).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (177).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (83).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (93).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (194).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (29).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (65).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (128).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (77).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (25).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (113).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (117).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (79).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (87).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (211).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (15).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (111).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (105).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (91).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (173).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (119).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (190).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (187).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (17).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (136).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (143).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (35).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (195).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (206).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (10).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (72).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (22).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (57).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (130).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (204).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (202).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (6).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (23).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (21).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (169).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (106).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (151).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (174).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (138).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (48).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (209).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (112).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (139).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (43).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (164).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (165).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (116).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (99).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (68).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (155).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (198).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (210).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (85).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (67).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (141).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (178).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (76).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (26).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (107).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (41).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (20).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (42).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (1).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (69).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (146).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (44).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (125).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (45).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (149).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (92).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (170).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (124).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (176).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (40).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (88).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (168).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (110).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (207).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (163).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (96).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (30).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (81).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (182).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (54).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (159).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (160).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (52).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (166).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (12).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (203).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (61).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (101).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (121).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (34).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (24).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (80).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (97).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (140).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (94).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (108).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (183).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (144).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (150).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (185).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (131).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (197).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (78).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (19).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (27).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (82).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (28).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (50).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (172).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (161).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (86).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (63).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (53).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (55).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (196).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (133).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (127).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (66).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (115).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (158).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (157).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (132).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (126).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (7).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (167).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (180).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (51).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (37).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (147).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (137).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (186).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (98).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (73).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (64).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (201).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (56).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (4).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (148).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (145).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (120).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (188).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (152).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (38).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (191).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (134).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (49).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (200).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (142).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (156).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (129).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Meloidogyne/Meloidogyne (70).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hemicycliophora/Hemicycliophora (3).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hemicycliophora/Hemicycliophora (2).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hemicycliophora/Hemicycliophora (1).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hemicycliophora/Hemicycliophora (6).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hemicycliophora/Hemicycliophora (5).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hemicycliophora/Hemicycliophora (4).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (9).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (12).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (110).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (29).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (86).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (103).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (28).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (97).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (59).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (4).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (91).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (32).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (52).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (74).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (95).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (66).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (113).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (111).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (46).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (90).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (105).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (53).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (56).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (98).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (62).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (45).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (51).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (27).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (39).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (6).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (64).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (50).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (81).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (25).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (13).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (15).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (5).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (48).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (63).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (79).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (76).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (78).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (94).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (40).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (84).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (71).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (54).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (41).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (8).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (108).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (20).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (26).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (21).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (31).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (100).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (57).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (106).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (87).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (16).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (107).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (102).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (34).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (72).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (68).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (88).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (30).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (73).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (7).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (70).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (36).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (83).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (22).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (93).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (89).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (38).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (24).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (18).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (69).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (75).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (60).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (92).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (58).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (116).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (115).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (17).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (35).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (101).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (37).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (11).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (67).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (19).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (112).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (65).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (1).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (14).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (42).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (2).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (44).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (49).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (85).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (55).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (47).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (109).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (43).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (77).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (33).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (61).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (96).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (114).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (104).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (3).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (82).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (10).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (80).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (23).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Pratylenchus/Pratylenchus (99).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (86).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (8).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (42).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (126).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (117).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (120).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (125).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (25).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (47).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (24).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (119).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (68).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (108).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (128).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (36).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (64).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (18).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (104).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (2).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (34).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (73).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (53).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (60).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (31).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (5).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (69).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (130).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (74).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (44).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (105).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (56).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (35).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (93).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (129).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (114).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (61).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (33).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (17).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (76).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (127).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (9).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (95).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (77).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (80).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (40).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (75).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (72).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (28).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (96).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (83).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (97).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (55).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (3).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (81).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (103).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (118).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (113).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (32).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (88).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (58).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (45).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (59).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (79).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (54).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (48).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (46).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (63).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Hirschmaniella/Hirschmaniella (41).jpg
# ...
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (72).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (56).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (28).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (47).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (18).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (13).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (2).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (50).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (38).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (36).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (21).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (65).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (78).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (76).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (77).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (68).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (35).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (23).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (85).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (41).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (7).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (79).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (45).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (22).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (63).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (12).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (27).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (81).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (17).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (14).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (6).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (60).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (44).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (57).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (51).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (1).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (70).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (46).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (3).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (33).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (73).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (37).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (26).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (64).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (32).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (11).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (29).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (5).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (83).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (30).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (55).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (67).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (71).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (8).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (10).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (59).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (62).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (80).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (20).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Xiphinema/Xiphinema (19).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Criconema/criconema (1).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Criconema/criconema (3).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Criconema/criconema (2).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Criconema/criconema (4).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (34).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (9).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (44).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (40).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (33).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (20).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (14).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (30).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (27).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (31).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (23).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (21).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (16).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (29).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (36).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (22).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (13).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (42).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (1).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (32).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (10).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (24).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (37).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (8).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (7).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (6).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (25).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (11).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (35).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (12).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (3).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (4).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (5).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (19).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (38).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (2).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (39).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (15).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (43).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (17).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (41).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (28).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (18).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (26).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (5).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (30).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (24).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (20).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (14).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (12).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (21).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (11).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (22).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (29).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (17).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (4).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (16).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (18).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (26).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (7).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (9).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (15).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (1).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (27).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (3).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (6).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (2).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (28).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (13).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (25).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (23).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (10).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (19).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (8).jpg
# /kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (31).jpg

# %%
# !pip install thop
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from thop) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2025.9.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->thop)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->thop)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->thop)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->thop)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->thop)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->thop)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->thop) (3.0.2)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.5 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, thop
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 thop-0.1.1.post2209072238

# %%
# ===============================================================
# 🔰 লাইব্রেরি ইমপোর্ট
# ===============================================================
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
import numpy as np
from tqdm import tqdm
import os, time
from thop import profile  # GFLOPs

# %%
# ===============================================================
# 🔰 GPU ব্যবহার
# ===============================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# ===============================================================
# 🔰 ডেটাসেট লোকেশন (নিজের পথটি দিন)
# ===============================================================
DATA_DIR ="/kaggle/input/nematoda/Microscopic Image Dataset of Plant-Parasitic Nematodes"
# ===============================================================
# 🔰 ডেটা ট্রান্সফর্মেশন
# ===============================================================
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
# ===============================================================
# 🔰 ImageFolder দিয়ে ডেটা লোড করা
# ===============================================================
dataset = datasets.ImageFolder(DATA_DIR, transform=transform)

# ===============================================================
# 🔰 Train/Test বিভাজন 70:30
# ===============================================================
test_ratio = 0.3
test_size = int(test_ratio * len(dataset))
train_size = len(dataset) - test_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])
print(f"Train: {len(train_dataset)}, Test: {len(test_dataset)}")
# Out:
# Train: 712, Test: 304

# %%
# ===============================================================
# 🔰 Train সেটের মধ্যে থেকে ১০% validation আলাদা করা
# ===============================================================
val_ratio = 0.1
val_size = int(val_ratio * len(train_dataset))
train_size_final = len(train_dataset) - val_size
train_dataset, val_dataset = random_split(train_dataset, [train_size_final, val_size])
print(f"Train: {len(train_dataset)}, Validation: {len(val_dataset)}, Test: {len(test_dataset)}")
# Out:
# Train: 641, Validation: 71, Test: 304

# %%
# ===============================================================
# 🔰 DataLoader সেটআপ
# ===============================================================
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# ===============================================================
# 🔰 Model setup
# ===============================================================
model = models.resnet50(pretrained=True)
num_classes = len(dataset.classes)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 197MB/s]

# %%
# ===============================================================
# 🔰 Training functions
# ===============================================================
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for images, labels in tqdm(loader, desc="Training", leave=False):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
    return running_loss / total, correct / total

def evaluate(model, loader, criterion):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0
    all_preds, all_labels, all_probs = [], [], []
    with torch.no_grad():
        for images, labels in tqdm(loader, desc="Evaluating", leave=False):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * images.size(0)
            _, preds = torch.max(outputs, 1)
            probs = torch.softmax(outputs, dim=1)

            correct += (preds == labels).sum().item()
            total += labels.size(0)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())
    return running_loss / total, correct / total, np.array(all_preds), np.array(all_labels), np.array(all_probs)

# %%
# ===============================================================
# 🔰 Training loop
# ===============================================================
num_epochs = 50
train_losses, val_losses = [], []
train_accs, val_accs = [], []

best_val_acc = 0.0
start_time = time.time()
for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion)
    val_loss, val_acc, _, _, _ = evaluate(model, val_loader, criterion)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accs.append(train_acc)
    val_accs.append(val_acc)

    print(f"Train Loss: {train_loss:.4f}, Acc: {train_acc:.4f} | Val Loss: {val_loss:.4f}, Acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_resnet50_model.pth")

end_time = time.time()
train_time = end_time - start_time
print(f"\n✅ Total training time: {train_time:.2f} sec")
# Out:
# Epoch 1/50
# Train Loss: 1.7625, Acc: 0.4321 | Val Loss: 1.2714, Acc: 0.5775
#
# Epoch 2/50
# Train Loss: 0.6343, Acc: 0.8612 | Val Loss: 0.8662, Acc: 0.7606
#
# Epoch 3/50
# Train Loss: 0.1813, Acc: 0.9735 | Val Loss: 0.6429, Acc: 0.8592
#
# Epoch 4/50
# Train Loss: 0.0681, Acc: 0.9875 | Val Loss: 0.6589, Acc: 0.8028
#
# Epoch 5/50
# Train Loss: 0.0489, Acc: 0.9938 | Val Loss: 0.6913, Acc: 0.8169
#
# Epoch 6/50
# Train Loss: 0.0446, Acc: 0.9938 | Val Loss: 0.6935, Acc: 0.7746
#
# Epoch 7/50
# Train Loss: 0.0394, Acc: 0.9938 | Val Loss: 0.5653, Acc: 0.8310
#
# Epoch 8/50
# Train Loss: 0.0534, Acc: 0.9891 | Val Loss: 0.9153, Acc: 0.7746
#
# Epoch 9/50
# Train Loss: 0.0893, Acc: 0.9750 | Val Loss: 0.7655, Acc: 0.7746
#
# Epoch 10/50
# Train Loss: 0.0573, Acc: 0.9875 | Val Loss: 1.0573, Acc: 0.7746
#
# Epoch 11/50
# Train Loss: 0.0450, Acc: 0.9922 | Val Loss: 1.0049, Acc: 0.7183
#
# Epoch 12/50
# Train Loss: 0.0266, Acc: 0.9953 | Val Loss: 0.8116, Acc: 0.8310
#
# Epoch 13/50
# Train Loss: 0.0334, Acc: 0.9938 | Val Loss: 0.7569, Acc: 0.7746
#
# Epoch 14/50
# Train Loss: 0.0255, Acc: 0.9938 | Val Loss: 0.8959, Acc: 0.7746
#
# Epoch 15/50
# Train Loss: 0.0413, Acc: 0.9953 | Val Loss: 0.8606, Acc: 0.7746
#
# Epoch 16/50
# Train Loss: 0.0402, Acc: 0.9906 | Val Loss: 0.8997, Acc: 0.7324
#
# Epoch 17/50
# Train Loss: 0.0366, Acc: 0.9922 | Val Loss: 0.8101, Acc: 0.7606
#
# Epoch 18/50
# Train Loss: 0.0542, Acc: 0.9860 | Val Loss: 0.9329, Acc: 0.7324
#
# Epoch 19/50
# Train Loss: 0.0592, Acc: 0.9860 | Val Loss: 0.8475, Acc: 0.7606
#
# Epoch 20/50
# Train Loss: 0.0365, Acc: 0.9922 | Val Loss: 0.8291, Acc: 0.7887
#
# Epoch 21/50
# Train Loss: 0.0256, Acc: 0.9938 | Val Loss: 0.8545, Acc: 0.7606
#
# Epoch 22/50
# Train Loss: 0.0241, Acc: 0.9922 | Val Loss: 0.7895, Acc: 0.8028
#
# Epoch 23/50
# Train Loss: 0.0299, Acc: 0.9922 | Val Loss: 0.5874, Acc: 0.8451
#
# Epoch 24/50
# Train Loss: 0.0247, Acc: 0.9953 | Val Loss: 0.6652, Acc: 0.7606
#
# Epoch 25/50
# Train Loss: 0.0450, Acc: 0.9875 | Val Loss: 0.8653, Acc: 0.7887
#
# Epoch 26/50
# Train Loss: 0.0448, Acc: 0.9906 | Val Loss: 0.8000, Acc: 0.7746
#
# Epoch 27/50
# Train Loss: 0.0532, Acc: 0.9860 | Val Loss: 0.8379, Acc: 0.7887
#
# Epoch 28/50
# Train Loss: 0.0294, Acc: 0.9938 | Val Loss: 0.7573, Acc: 0.8028
#
# Epoch 29/50
# Train Loss: 0.0225, Acc: 0.9922 | Val Loss: 0.9058, Acc: 0.7183
#
# Epoch 30/50
# Train Loss: 0.0168, Acc: 0.9969 | Val Loss: 0.7632, Acc: 0.7887
#
# Epoch 31/50
# Train Loss: 0.0159, Acc: 0.9984 | Val Loss: 0.8355, Acc: 0.8028
#
# Epoch 32/50
# Train Loss: 0.0184, Acc: 0.9969 | Val Loss: 0.7709, Acc: 0.7887
#
# Epoch 33/50
# Train Loss: 0.0176, Acc: 0.9953 | Val Loss: 0.7593, Acc: 0.8310
#
# Epoch 34/50
# Train Loss: 0.0389, Acc: 0.9906 | Val Loss: 1.4019, Acc: 0.7324
#
# Epoch 35/50
# Train Loss: 0.0421, Acc: 0.9891 | Val Loss: 0.8828, Acc: 0.8310
#
# Epoch 36/50
# Train Loss: 0.0467, Acc: 0.9906 | Val Loss: 0.6978, Acc: 0.8310
#
# Epoch 37/50
# Train Loss: 0.0266, Acc: 0.9922 | Val Loss: 0.6270, Acc: 0.8028
#
# Epoch 38/50
# Train Loss: 0.0185, Acc: 0.9953 | Val Loss: 0.6344, Acc: 0.8028
#
# Epoch 39/50
# Train Loss: 0.0181, Acc: 0.9969 | Val Loss: 0.6684, Acc: 0.8310
#
# Epoch 40/50
# Train Loss: 0.0145, Acc: 0.9969 | Val Loss: 0.6035, Acc: 0.8732
#
# Epoch 41/50
# Train Loss: 0.0155, Acc: 0.9969 | Val Loss: 0.7335, Acc: 0.8028
#
# Epoch 42/50
# Train Loss: 0.0116, Acc: 0.9984 | Val Loss: 0.9389, Acc: 0.8028
#
# Epoch 43/50
# Train Loss: 0.0136, Acc: 0.9969 | Val Loss: 0.8291, Acc: 0.7887
#
# Epoch 44/50
# Train Loss: 0.0149, Acc: 0.9953 | Val Loss: 0.7479, Acc: 0.7746
#
# Epoch 45/50
# Train Loss: 0.0178, Acc: 0.9969 | Val Loss: 0.6343, Acc: 0.8169
#
# Epoch 46/50
# Train Loss: 0.0175, Acc: 0.9969 | Val Loss: 0.7612, Acc: 0.8169
#
# Epoch 47/50
# Train Loss: 0.0235, Acc: 0.9953 | Val Loss: 0.5537, Acc: 0.8732
#
# Epoch 48/50
# Train Loss: 0.0224, Acc: 0.9953 | Val Loss: 0.5990, Acc: 0.8169
#
# Epoch 49/50
# Train Loss: 0.0337, Acc: 0.9906 | Val Loss: 0.7071, Acc: 0.8028
#
# Epoch 50/50
# Train Loss: 0.0443, Acc: 0.9875 | Val Loss: 0.6938, Acc: 0.8028
#
# ✅ Total training time: 983.42 sec

# %%
# ===============================================================
# 🔰 Plot Loss & Accuracy
# ===============================================================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(train_accs, label="Train Acc")
plt.plot(val_accs, label="Val Acc")
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# ===============================================================
# 🔰 Test evaluation
# ===============================================================
model.load_state_dict(torch.load("best_resnet50_model.pth"))
test_start = time.time()
test_loss, test_acc, all_preds, all_labels, all_probs = evaluate(model, test_loader, criterion)
test_end = time.time()
test_time = test_end - test_start
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"✅ Test time: {test_time:.2f} sec")
# Out:
# ✅ Test Accuracy: 83.22%
# ✅ Test time: 8.73 sec

# %%
# ===============================================================
# 🔰 Classification report, Per-class accuracy & Confusion Matrix
# ===============================================================
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

# ✅ Model evaluation on test set
all_preds, all_labels = [], []
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# ✅ Only test set labels
unique_labels = sorted(list(set(all_labels)))
target_names = [dataset.classes[i] for i in unique_labels]

# ✅ Classification Report
print("\nClassification Report:")
print(classification_report(all_labels, all_preds, labels=unique_labels, target_names=target_names, digits=4))

# ✅ Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(8,6))
plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.colorbar()
plt.show()

# ✅ Per-class accuracy (fixed)
per_class_acc = cm.diagonal() / cm.sum(axis=1)
print("\nPer-class Accuracy:")
for i, label_idx in enumerate(unique_labels):
    cls_name = dataset.classes[label_idx]
    print(f"{cls_name}: {per_class_acc[i]*100:.2f}%")
# Out:
# Classification Report:
#                        precision    recall  f1-score   support
#
#       Genus Criconema     0.0000    0.0000    0.0000         3
#   Genus Criconemoides     0.8966    0.8966    0.8966        29
# Genus Helicotylenchus     0.8846    0.9787    0.9293        47
# Genus Hemicycliophora     0.0000    0.0000    0.0000         3
#  Genus Hirschmaniella     0.7805    0.7805    0.7805        41
#     Genus Hoplolaimus     0.9000    0.9000    0.9000        40
#     Genus Meloidogyne     0.9348    0.7167    0.8113        60
#    Genus Pratylenchus     0.6667    0.7333    0.6984        30
#      Genus Radopholus     0.6154    0.8000    0.6957        10
#     Genus Trichodorus     0.8636    1.0000    0.9268        19
#       Genus Xiphinema     0.7500    0.9545    0.8400        22
#
#              accuracy                         0.8322       304
#             macro avg     0.6629    0.7055    0.6799       304
#          weighted avg     0.8248    0.8322    0.8235       304
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Per-class Accuracy:
# Genus Criconema: 0.00%
# Genus Criconemoides: 89.66%
# Genus Helicotylenchus: 97.87%
# Genus Hemicycliophora: 0.00%
# Genus Hirschmaniella: 78.05%
# Genus Hoplolaimus: 90.00%
# Genus Meloidogyne: 71.67%
# Genus Pratylenchus: 73.33%
# Genus Radopholus: 80.00%
# Genus Trichodorus: 100.00%
# Genus Xiphinema: 95.45%

# %%
# ===============================================================
# 🔰 ROC-AUC per class (fixed)
# ===============================================================
all_labels_np = np.array(all_labels)
all_probs_np = np.array(all_probs)

plt.figure(figsize=(10,8))
for i, cls in enumerate(dataset.classes):
    # Convert to boolean array for current class
    y_true = (all_labels_np == i).astype(int)  # 0/1 labels
    y_score = all_probs_np[:, i]               # predicted probability for class i

    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{cls} (AUC = {roc_auc:.4f})')

plt.plot([0,1],[0,1],'k--')
plt.title("ROC Curves")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

# %%
# Model GFLOPs & Params calculation
model.eval()
dummy_input = torch.randn(1, 3, 224, 224).to(device)  # ResNet-50 input
flops, params = profile(model, inputs=(dummy_input,))

print(f"\n✅ Model Complexity:")
print(f"FLOPs: {flops / 1e9:.2f} GFLOPs")
print(f"Parameters: {params / 1e6:.2f} M")
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
#
# ✅ Model Complexity:
# FLOPs: 4.13 GFLOPs
# Parameters: 23.53 M
