jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (34).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (9).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (44).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (40).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (33).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (20).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (14).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (30).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (27).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (31).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (23).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (21).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (16).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (29).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (36).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (22).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (13).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (42).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (1).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (32).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (10).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (24).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (37).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (8).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (7).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (6).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (25).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (11).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (35).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (12).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (3).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (4).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (5).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (19).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (38).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (2).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (39).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (15).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (43).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (17).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (41).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (28).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (18).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Trichodorus/Trichodorus (26).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (5).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (30).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (24).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (20).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (14).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (12).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (21).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (11).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (22).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (29).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (17).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (4).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (16).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (18).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (26).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (7).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (9).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (15).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (1).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (27).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (3).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (6).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (2).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (28).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (13).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (25).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (23).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (10).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (19).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (8).jpg
# /kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes/Genus Radopholus/Radopholus (31).jpg

# %%
# !pip install thop
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from thop) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2025.9.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->thop)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->thop)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->thop)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->thop)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->thop)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->thop)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->thop) (3.0.2)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, thop
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 thop-0.1.1.post2209072238

# %%
# =============================
# 1️⃣ Imports
# =============================
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.utils.multiclass import unique_labels
import numpy as np
import time
from thop import profile
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

# =============================
# 2️⃣ Dataset & Transforms
# =============================
DATA_DIR = "/kaggle/input/plant-parasitic-nematodes-3070/Microscopic Image Dataset of Plant-Parasitic Nematodes"

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(DATA_DIR, transform=transform)
num_classes = len(dataset.classes)

# =============================
# 3️⃣ Train/Test/Validation split (30:70) 
# =============================
test_ratio = 0.7
test_size = int(test_ratio * len(dataset))
train_size = len(dataset) - test_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# Validation = 10% of train
val_ratio = 0.1
val_size = int(val_ratio * len(train_dataset))
train_size_final = len(train_dataset) - val_size
train_dataset, val_dataset = random_split(train_dataset, [train_size_final, val_size])

print(f"Train: {len(train_dataset)}, Validation: {len(val_dataset)}, Test: {len(test_dataset)}")

# DataLoaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# =============================
# 4️⃣ Model (Pretrained EfficientNet-B0)
# =============================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, num_classes)
model = model.to(device)

# Loss & Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# =============================
# 5️⃣ Training Loop
# =============================
num_epochs = 50
train_losses, val_losses = [], []
train_accs, val_accs = [], []

start_time = time.time()

for epoch in range(num_epochs):
    model.train()
    running_loss, correct, total = 0, 0, 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * images.size(0)
        _, predicted = outputs.max(1)
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
    
    train_loss = running_loss / total
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    
    # Validation
    model.eval()
    val_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            correct += predicted.eq(labels).sum().item()
            total += labels.size(0)
    val_loss /= total
    val_acc = correct / total
    val_losses.append(val_loss)
    val_accs.append(val_acc)
    
    print(f"Epoch [{epoch+1}/{num_epochs}] | "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} | "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

end_time = time.time()
print(f"Training wall-clock time: {(end_time-start_time)/60:.2f} mins")

# =============================
# 6️⃣ Loss & Accuracy Curves
# =============================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.title('Loss Curve')

plt.subplot(1,2,2)
plt.plot(train_accs, label='Train Accuracy')
plt.plot(val_accs, label='Validation Accuracy')
plt.legend()
plt.title('Accuracy Curve')
plt.show()

# =============================
# 7️⃣ Test Evaluation
# =============================
model.eval()
all_labels, all_preds, all_probs = [], [], []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = F.softmax(outputs, dim=1)
        _, predicted = outputs.max(1)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(predicted.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

# Overall Accuracy
overall_acc = accuracy_score(all_labels, all_preds)
print(f"\n✅ Overall Accuracy: {overall_acc*100:.2f}%")

# Per-Class Accuracy
cm = confusion_matrix(all_labels, all_preds)
per_class_acc = cm.diagonal() / cm.sum(axis=1)
print("\n📊 Per-Class Accuracy:")
for i, acc in enumerate(per_class_acc):
    print(f"{dataset.classes[i]}: {acc*100:.2f}%")

# Classification Report (handles missing classes)
labels_present = unique_labels(all_labels, all_preds)
print("\nClassification Report:")
print(classification_report(
    all_labels,
    all_preds,
    labels=labels_present,
    target_names=[dataset.classes[i] for i in labels_present]
))

# Confusion Matrix Plot
plt.figure(figsize=(8,6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
plt.xticks(range(num_classes), dataset.classes, rotation=45)
plt.yticks(range(num_classes), dataset.classes)
plt.show()

# =============================
# 8️⃣ ROC Curves (All 11 classes)
# =============================
labels_bin = label_binarize(all_labels, classes=range(num_classes))
all_probs = np.array(all_probs)

# Pad missing classes if any
if labels_bin.shape[1] < num_classes:
    pad_cols = num_classes - labels_bin.shape[1]
    labels_bin = np.hstack((labels_bin, np.zeros((labels_bin.shape[0], pad_cols))))
    all_probs = np.hstack((all_probs, np.zeros((all_probs.shape[0], pad_cols))))

fpr, tpr, roc_auc = {}, {}, {}
plt.figure(figsize=(8,6))

for i in range(num_classes):
    y_true_class = labels_bin[:, i]
    y_score_class = all_probs[:, i]

    # Ensure at least one positive & negative for ROC
    if len(np.unique(y_true_class)) < 2:
        y_true_class = np.append(y_true_class, [0, 1])
        y_score_class = np.append(y_score_class, [0, 1])

    fpr[i], tpr[i], _ = roc_curve(y_true_class, y_score_class)
    roc_auc[i] = roc_auc_score(y_true_class, y_score_class)
    plt.plot(fpr[i], tpr[i], label=f'{dataset.classes[i]} (AUC={roc_auc[i]:.2f})')

plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves (All 11 Classes)')
plt.legend()
plt.show()

# =============================
# 9️⃣ GFLOPs per inference
# =============================
dummy_input = torch.randn(1, 3, 224, 224).to(device)
macs, params = profile(model, inputs=(dummy_input,), verbose=False)
gflops = macs / 1e9
print(f"GFLOPs per inference at 224x224: {gflops:.2f} GFLOPs")
# Out:
# Train: 275, Validation: 30, Test: 711
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 133MB/s]
# Epoch [1/50] | Train Loss: 2.3489, Train Acc: 0.1418 | Val Loss: 2.3670, Val Acc: 0.0667
# Epoch [2/50] | Train Loss: 2.0972, Train Acc: 0.4400 | Val Loss: 2.2951, Val Acc: 0.1000
# Epoch [3/50] | Train Loss: 1.8954, Train Acc: 0.5818 | Val Loss: 2.1927, Val Acc: 0.2000
# Epoch [4/50] | Train Loss: 1.6890, Train Acc: 0.6655 | Val Loss: 2.0351, Val Acc: 0.3000
# Epoch [5/50] | Train Loss: 1.4822, Train Acc: 0.7564 | Val Loss: 1.9243, Val Acc: 0.4000
# Epoch [6/50] | Train Loss: 1.3109, Train Acc: 0.7964 | Val Loss: 1.8218, Val Acc: 0.4000
# Epoch [7/50] | Train Loss: 1.1505, Train Acc: 0.8400 | Val Loss: 1.7187, Val Acc: 0.4667
# Epoch [8/50] | Train Loss: 0.9912, Train Acc: 0.8945 | Val Loss: 1.6221, Val Acc: 0.5000
# Epoch [9/50] | Train Loss: 0.8661, Train Acc: 0.8800 | Val Loss: 1.5611, Val Acc: 0.4667
# Epoch [10/50] | Train Loss: 0.7194, Train Acc: 0.9309 | Val Loss: 1.5320, Val Acc: 0.5333
# Epoch [11/50] | Train Loss: 0.6025, Train Acc: 0.9309 | Val Loss: 1.4971, Val Acc: 0.5333
# Epoch [12/50] | Train Loss: 0.4972, Train Acc: 0.9636 | Val Loss: 1.4185, Val Acc: 0.5667
# Epoch [13/50] | Train Loss: 0.4010, Train Acc: 0.9782 | Val Loss: 1.3679, Val Acc: 0.5333
# Epoch [14/50] | Train Loss: 0.3529, Train Acc: 0.9673 | Val Loss: 1.3470, Val Acc: 0.6000
# Epoch [15/50] | Train Loss: 0.2652, Train Acc: 0.9818 | Val Loss: 1.3189, Val Acc: 0.6333
# Epoch [16/50] | Train Loss: 0.2335, Train Acc: 0.9927 | Val Loss: 1.3001, Val Acc: 0.6333
# Epoch [17/50] | Train Loss: 0.2209, Train Acc: 0.9855 | Val Loss: 1.2839, Val Acc: 0.6333
# Epoch [18/50] | Train Loss: 0.1702, Train Acc: 0.9855 | Val Loss: 1.3269, Val Acc: 0.6333
# Epoch [19/50] | Train Loss: 0.1486, Train Acc: 0.9855 | Val Loss: 1.3432, Val Acc: 0.6000
# Epoch [20/50] | Train Loss: 0.1392, Train Acc: 0.9891 | Val Loss: 1.3601, Val Acc: 0.6000
# Epoch [21/50] | Train Loss: 0.1186, Train Acc: 0.9891 | Val Loss: 1.3957, Val Acc: 0.6000
# Epoch [22/50] | Train Loss: 0.0856, Train Acc: 1.0000 | Val Loss: 1.3871, Val Acc: 0.6333
# Epoch [23/50] | Train Loss: 0.0927, Train Acc: 0.9891 | Val Loss: 1.3811, Val Acc: 0.6333
# Epoch [24/50] | Train Loss: 0.0726, Train Acc: 0.9964 | Val Loss: 1.3868, Val Acc: 0.6333
# Epoch [25/50] | Train Loss: 0.0695, Train Acc: 0.9964 | Val Loss: 1.3686, Val Acc: 0.6333
# Epoch [26/50] | Train Loss: 0.0753, Train Acc: 0.9927 | Val Loss: 1.3282, Val Acc: 0.6000
# Epoch [27/50] | Train Loss: 0.0526, Train Acc: 1.0000 | Val Loss: 1.3078, Val Acc: 0.6333
# Epoch [28/50] | Train Loss: 0.0521, Train Acc: 0.9964 | Val Loss: 1.3387, Val Acc: 0.6333
# Epoch [29/50] | Train Loss: 0.0580, Train Acc: 0.9964 | Val Loss: 1.4620, Val Acc: 0.6333
# Epoch [30/50] | Train Loss: 0.0423, Train Acc: 1.0000 | Val Loss: 1.5337, Val Acc: 0.6333
# Epoch [31/50] | Train Loss: 0.0619, Train Acc: 0.9964 | Val Loss: 1.5130, Val Acc: 0.6333
# Epoch [32/50] | Train Loss: 0.0341, Train Acc: 1.0000 | Val Loss: 1.5104, Val Acc: 0.6333
# Epoch [33/50] | Train Loss: 0.0367, Train Acc: 0.9964 | Val Loss: 1.5078, Val Acc: 0.6333
# Epoch [34/50] | Train Loss: 0.0360, Train Acc: 0.9964 | Val Loss: 1.5042, Val Acc: 0.6333
# Epoch [35/50] | Train Loss: 0.0320, Train Acc: 0.9964 | Val Loss: 1.5200, Val Acc: 0.6000
# Epoch [36/50] | Train Loss: 0.0344, Train Acc: 0.9964 | Val Loss: 1.5728, Val Acc: 0.6000
# Epoch [37/50] | Train Loss: 0.0262, Train Acc: 0.9964 | Val Loss: 1.6114, Val Acc: 0.6000
# Epoch [38/50] | Train Loss: 0.0340, Train Acc: 0.9964 | Val Loss: 1.5731, Val Acc: 0.6000
# Epoch [39/50] | Train Loss: 0.0337, Train Acc: 0.9964 | Val Loss: 1.5905, Val Acc: 0.6000
# Epoch [40/50] | Train Loss: 0.0266, Train Acc: 1.0000 | Val Loss: 1.5622, Val Acc: 0.6000
# Epoch [41/50] | Train Loss: 0.0222, Train Acc: 1.0000 | Val Loss: 1.5655, Val Acc: 0.6333
# Epoch [42/50] | Train Loss: 0.0238, Train Acc: 0.9964 | Val Loss: 1.5513, Val Acc: 0.6333
# Epoch [43/50] | Train Loss: 0.0260, Train Acc: 1.0000 | Val Loss: 1.5939, Val Acc: 0.6000
# Epoch [44/50] | Train Loss: 0.0109, Train Acc: 1.0000 | Val Loss: 1.6065, Val Acc: 0.6333
# Epoch [45/50] | Train Loss: 0.0217, Train Acc: 1.0000 | Val Loss: 1.6096, Val Acc: 0.6333
# Epoch [46/50] | Train Loss: 0.0164, Train Acc: 0.9964 | Val Loss: 1.6118, Val Acc: 0.6000
# Epoch [47/50] | Train Loss: 0.0204, Train Acc: 0.9964 | Val Loss: 1.6460, Val Acc: 0.6000
# Epoch [48/50] | Train Loss: 0.0228, Train Acc: 0.9964 | Val Loss: 1.5755, Val Acc: 0.6000
# Epoch [49/50] | Train Loss: 0.0131, Train Acc: 1.0000 | Val Loss: 1.5101, Val Acc: 0.6333
# Epoch [50/50] | Train Loss: 0.0169, Train Acc: 1.0000 | Val Loss: 1.5228, Val Acc: 0.6333
# Training wall-clock time: 5.34 mins
# ✅ Overall Accuracy: 67.65%
#
# 📊 Per-Class Accuracy:
# Genus Criconema: 0.00%
# Genus Criconemoides: 85.29%
# Genus Helicotylenchus: 82.98%
# Genus Hemicycliophora: 0.00%
# Genus Hirschmaniella: 51.55%
# Genus Hoplolaimus: 87.88%
# Genus Meloidogyne: 62.99%
# Genus Pratylenchus: 54.32%
# Genus Radopholus: 52.17%
# Genus Trichodorus: 80.65%
# Genus Xiphinema: 52.63%
#
# Classification Report:
#                        precision    recall  f1-score   support
#
#       Genus Criconema       0.00      0.00      0.00         2
#   Genus Criconemoides       0.83      0.85      0.84        68
# Genus Helicotylenchus       0.73      0.83      0.78        94
# Genus Hemicycliophora       0.00      0.00      0.00         5
#  Genus Hirschmaniella       0.70      0.52      0.60        97
#     Genus Hoplolaimus       0.58      0.88      0.70        99
#     Genus Meloidogyne       0.80      0.63      0.70       154
#    Genus Pratylenchus       0.42      0.54      0.47        81
#      Genus Radopholus       0.86      0.52      0.65        23
#     Genus Trichodorus       0.86      0.81      0.83        31
#       Genus Xiphinema       0.73      0.53      0.61        57
#
#              accuracy                           0.68       711
#             macro avg       0.59      0.55      0.56       711
#          weighted avg       0.70      0.68      0.67       711
# GFLOPs per inference at 224x224: 0.41 GFLOPs
